# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img=cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
#matplot lib #RGB 
#blue Green red 
fix_img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray=cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
temp=cv2.resize(fix_img,(100,500))
plt.imshow(temp)

# %%
w_ratio=0.5
h_ratio=0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img=cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
#cv2.imwrite("Path",source_file)

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(fix_img)

# %%
import cv2
img=cv2.imread('DATA/00-puppy.jpg')
cv2.imshow("puppy",img)
cv2.waitKey()
# Out:
# -1

# %%
print("sfasd")
# Out:
# sfasd
